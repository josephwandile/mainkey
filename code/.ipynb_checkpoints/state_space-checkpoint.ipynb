# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import pickle
import seaborn
# Out:
# /Library/Python/2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
# NB: The line below assumes states which have already been processed using the commented out lines
# lower in the cell. If you're importing directly from stub.py you'll need to use the code that's commented out.
monkey_states, tree_states = pickle.load(open('multiple_g_states.pkl', 'rb'))
# monkey_states = pd.DataFrame([state['monkey'] for state in state_space])
# tree_states = pd.DataFrame([state['tree'] for state in state_space])

# %%
monkey_states.head()
# Out:
#    bot  top  vel
# 0  200  256    0
# 1  200  256   -1
# 2  199  255   -2
# 3  197  253   -3
# 4  194  250   -4

# %%
tree_states.head()
# Out:
#    bot  dist  top
# 0   54   485  254
# 1   54   460  254
# 2   54   435  254
# 3   54   410  254
# 4   54   385  254

# %% [markdown]
# #### NB The velocities below are pulled from a variety of gravity measures. i.e. g = 1 ... 4

# %%
plt.figure()
plt.hist(monkey_states['vel'].values, bins=100)
plt.title('Distribution of velocity measures.')

# %%
plt.figure()
plt.hist(monkey_states['bot'].values, bins=100)
plt.title('Distribution of monkey butt heights.')

# %%
plt.figure()
plt.hist(monkey_states['top'].values, bins=100)
plt.title('Distribution of monkey head heights.')

# %%
plt.figure()
plt.hist(tree_states['top'].values, bins=100)
plt.title('Distribution of tree top heights.')

# %%
plt.figure()
plt.hist(tree_states['bot'].values, bins=100)
plt.title('Distribution of tree bottom heights.')

# %%
plt.figure()
plt.hist(tree_states['dist'].values, bins=100)
plt.title('Distribution of monkey distance from tree.')
